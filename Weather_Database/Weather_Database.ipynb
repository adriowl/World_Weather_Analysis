# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print(coordinates[:10])
# Out:
# [(37.69279284303397, 92.60048381181008), (18.498217010851974, 163.23263928932732), (53.46195901660337, 107.33596406702992), (16.02136496912364, 24.921343520369874), (-88.92708376941066, -171.8497592277258), (45.96676779353433, -154.4907528630994), (88.25248627608943, -62.440556204818265), (-38.848984740740335, 135.96046740941125), (81.3055991772695, -86.39672643067766), (-22.601589203049414, 3.959056020831099)]

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hami
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | khuzhir
# Processing Record 4 of Set 1 | kutum
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | narsaq
# Processing Record 8 of Set 1 | port lincoln
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | henties bay
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | nelson bay
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | gat
# Processing Record 15 of Set 1 | san jose
# Processing Record 16 of Set 1 | yendi
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | pevek
# Processing Record 19 of Set 1 | kui buri
# Processing Record 20 of Set 1 | nago
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | sapa
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | pemangkat
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 1 | el playon
# Processing Record 28 of Set 1 | umm lajj
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | savannah bight
# Processing Record 31 of Set 1 | torbay
# Processing Record 32 of Set 1 | luanda
# Processing Record 33 of Set 1 | egvekinot
# Processing Record 34 of Set 1 | astoria
# Processing Record 35 of Set 1 | luderitz
# Processing Record 36 of Set 1 | leningradskiy
# Processing Record 37 of Set 1 | vallenar
# Processing Record 38 of Set 1 | namibe
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | souillac
# Processing Record 42 of Set 1 | avera
# Processing Record 43 of Set 1 | saint-pierre
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | carnarvon
# Processing Record 47 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | hamilton
# Processing Record 2 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | norman wells
# Processing Record 5 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | kavieng
# Processing Record 8 of Set 2 | araguatins
# City not found. Skipping...
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 2 | ulladulla
# Processing Record 12 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 2 | scurtu mare
# Processing Record 14 of Set 2 | nyimba
# Processing Record 15 of Set 2 | sandpoint
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | oranjemund
# Processing Record 18 of Set 2 | bairnsdale
# Processing Record 19 of Set 2 | benidorm
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | hay river
# Processing Record 23 of Set 2 | ushuaia
# Processing Record 24 of Set 2 | lastoursville
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | yulara
# Processing Record 27 of Set 2 | inuvik
# Processing Record 28 of Set 2 | krasnoborsk
# Processing Record 29 of Set 2 | grand gaube
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | nome
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | roma
# Processing Record 36 of Set 2 | pimentel
# Processing Record 37 of Set 2 | santa marta
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | college
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 43 of Set 2 | bredy
# Processing Record 44 of Set 2 | itoman
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | warwick
# Processing Record 48 of Set 2 | charters towers
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | lata
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 3 | polunochnoye
# Processing Record 6 of Set 3 | shimoda
# Processing Record 7 of Set 3 | ribeira grande
# Processing Record 8 of Set 3 | keti bandar
# Processing Record 9 of Set 3 | sitka
# Processing Record 10 of Set 3 | saint-augustin
# Processing Record 11 of Set 3 | geraldton
# Processing Record 12 of Set 3 | maningrida
# Processing Record 13 of Set 3 | gragnano
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | tessalit
# Processing Record 16 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 3 | borodino
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | bougouni
# Processing Record 21 of Set 3 | qui nhon
# Processing Record 22 of Set 3 | katsuura
# Processing Record 23 of Set 3 | nioki
# Processing Record 24 of Set 3 | accrington
# Processing Record 25 of Set 3 | clyde river
# Processing Record 26 of Set 3 | hosanagara
# Processing Record 27 of Set 3 | nizhniy kuranakh
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | najran
# Processing Record 30 of Set 3 | popondetta
# Processing Record 31 of Set 3 | mataura
# Processing Record 32 of Set 3 | rupert
# Processing Record 33 of Set 3 | vaasa
# Processing Record 34 of Set 3 | cidreira
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | pishin
# Processing Record 37 of Set 3 | moose factory
# Processing Record 38 of Set 3 | anchorage
# Processing Record 39 of Set 3 | busselton
# Processing Record 40 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | tuy hoa
# Processing Record 43 of Set 3 | elizabeth city
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | codajas
# Processing Record 46 of Set 3 | biak
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | guerrero negro
# Processing Record 49 of Set 3 | abilene
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | viransehir
# Processing Record 2 of Set 4 | tabou
# Processing Record 3 of Set 4 | aklavik
# Processing Record 4 of Set 4 | ferme-neuve
# Processing Record 5 of Set 4 | mount gambier
# Processing Record 6 of Set 4 | na wa
# Processing Record 7 of Set 4 | san patricio
# Processing Record 8 of Set 4 | poum
# Processing Record 9 of Set 4 | barrow
# Processing Record 10 of Set 4 | rio de jesus
# Processing Record 11 of Set 4 | biscarrosse
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | lebu
# Processing Record 14 of Set 4 | maniitsoq
# Processing Record 15 of Set 4 | brownsville
# Processing Record 16 of Set 4 | tuatapere
# Processing Record 17 of Set 4 | dikson
# Processing Record 18 of Set 4 | sao joao da barra
# Processing Record 19 of Set 4 | naze
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | montecorvino rovella
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | coihaique
# Processing Record 26 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 4 | alpena
# Processing Record 28 of Set 4 | mount pleasant
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | abnub
# Processing Record 32 of Set 4 | melfi
# Processing Record 33 of Set 4 | nyurba
# Processing Record 34 of Set 4 | phalodi
# Processing Record 35 of Set 4 | maceio
# Processing Record 36 of Set 4 | ust-koksa
# Processing Record 37 of Set 4 | kedrovyy
# Processing Record 38 of Set 4 | cabo rojo
# Processing Record 39 of Set 4 | havre-saint-pierre
# Processing Record 40 of Set 4 | shache
# Processing Record 41 of Set 4 | lydenburg
# Processing Record 42 of Set 4 | shepsi
# Processing Record 43 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 4 | solnechnyy
# Processing Record 45 of Set 4 | barabai
# Processing Record 46 of Set 4 | fougeres
# Processing Record 47 of Set 4 | kitui
# Processing Record 48 of Set 4 | kruisfontein
# Processing Record 49 of Set 4 | pavilosta
# Processing Record 50 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 5 | kununurra
# Processing Record 3 of Set 5 | ostrovnoy
# Processing Record 4 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | kon tum
# Processing Record 7 of Set 5 | harper
# Processing Record 8 of Set 5 | mareeba
# Processing Record 9 of Set 5 | bo phloi
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | sainte-rose
# Processing Record 12 of Set 5 | bengkulu
# Processing Record 13 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | cherskiy
# Processing Record 15 of Set 5 | lucea
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | talaya
# Processing Record 18 of Set 5 | tulu bolo
# Processing Record 19 of Set 5 | lungi
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | trelleborg
# Processing Record 22 of Set 5 | leeton
# Processing Record 23 of Set 5 | east wenatchee bench
# Processing Record 24 of Set 5 | gorele
# Processing Record 25 of Set 5 | phalaborwa
# Processing Record 26 of Set 5 | abakaliki
# Processing Record 27 of Set 5 | boa vista
# Processing Record 28 of Set 5 | dunedin
# Processing Record 29 of Set 5 | oregon city
# Processing Record 30 of Set 5 | grand-bourg
# Processing Record 31 of Set 5 | altamont
# Processing Record 32 of Set 5 | kidal
# Processing Record 33 of Set 5 | binga
# Processing Record 34 of Set 5 | paamiut
# Processing Record 35 of Set 5 | fort nelson
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | margate
# Processing Record 38 of Set 5 | parrita
# Processing Record 39 of Set 5 | strezhevoy
# Processing Record 40 of Set 5 | laguna
# Processing Record 41 of Set 5 | parkes
# Processing Record 42 of Set 5 | kaitangata
# Processing Record 43 of Set 5 | qasigiannguit
# Processing Record 44 of Set 5 | petropavlovka
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | linxia
# Processing Record 47 of Set 5 | hualmay
# Processing Record 48 of Set 5 | padang
# Processing Record 49 of Set 5 | te anau
# Processing Record 50 of Set 5 | kapenguria
# Processing Record 1 of Set 6 | asau
# Processing Record 2 of Set 6 | provideniya
# Processing Record 3 of Set 6 | lorengau
# Processing Record 4 of Set 6 | basoko
# Processing Record 5 of Set 6 | mingguang
# Processing Record 6 of Set 6 | araouane
# Processing Record 7 of Set 6 | uhlove
# Processing Record 8 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 6 | druten
# Processing Record 10 of Set 6 | pemba
# Processing Record 11 of Set 6 | castro
# Processing Record 12 of Set 6 | alice springs
# Processing Record 13 of Set 6 | beranang
# Processing Record 14 of Set 6 | madang
# Processing Record 15 of Set 6 | waingapu
# Processing Record 16 of Set 6 | grootfontein
# Processing Record 17 of Set 6 | sibolga
# Processing Record 18 of Set 6 | port hardy
# Processing Record 19 of Set 6 | kibaya
# Processing Record 20 of Set 6 | bud
# Processing Record 21 of Set 6 | saint-louis
# Processing Record 22 of Set 6 | arrifes
# Processing Record 23 of Set 6 | labuan
# Processing Record 24 of Set 6 | beloha
# Processing Record 25 of Set 6 | pringsewu
# Processing Record 26 of Set 6 | borovoy
# Processing Record 27 of Set 6 | carutapera
# Processing Record 28 of Set 6 | jiayuguan
# Processing Record 29 of Set 6 | chuy
# Processing Record 30 of Set 6 | innisfail
# Processing Record 31 of Set 6 | tigil
# Processing Record 32 of Set 6 | sinnamary
# Processing Record 33 of Set 6 | maragogi
# Processing Record 34 of Set 6 | elko
# Processing Record 35 of Set 6 | winsum
# Processing Record 36 of Set 6 | kautokeino
# Processing Record 37 of Set 6 | vila franca do campo
# Processing Record 38 of Set 6 | rundu
# Processing Record 39 of Set 6 | kirakira
# Processing Record 40 of Set 6 | cascais
# Processing Record 41 of Set 6 | ammon
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | road town
# Processing Record 44 of Set 6 | husavik
# Processing Record 45 of Set 6 | januaria
# Processing Record 46 of Set 6 | warrington
# Processing Record 47 of Set 6 | sao filipe
# Processing Record 48 of Set 6 | seguela
# Processing Record 49 of Set 6 | llanes
# Processing Record 50 of Set 6 | sandakan
# Processing Record 1 of Set 7 | praya
# Processing Record 2 of Set 7 | bonavista
# Processing Record 3 of Set 7 | inirida
# Processing Record 4 of Set 7 | acajutla
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | dourbali
# Processing Record 7 of Set 7 | port-cartier
# Processing Record 8 of Set 7 | luz
# Processing Record 9 of Set 7 | kralendijk
# Processing Record 10 of Set 7 | porirua
# Processing Record 11 of Set 7 | byron bay
# Processing Record 12 of Set 7 | karachi
# Processing Record 13 of Set 7 | chapais
# Processing Record 14 of Set 7 | oskemen
# Processing Record 15 of Set 7 | tuktoyaktuk
# Processing Record 16 of Set 7 | mansa
# Processing Record 17 of Set 7 | klaksvik
# Processing Record 18 of Set 7 | laibin
# Processing Record 19 of Set 7 | borujan
# City not found. Skipping...
# Processing Record 20 of Set 7 | richards bay
# Processing Record 21 of Set 7 | port blair
# Processing Record 22 of Set 7 | luganville
# Processing Record 23 of Set 7 | lagoa
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | deputatskiy
# Processing Record 26 of Set 7 | gillette
# Processing Record 27 of Set 7 | rakitnoye
# Processing Record 28 of Set 7 | rio gallegos
# Processing Record 29 of Set 7 | necochea
# Processing Record 30 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 7 | fairbanks
# Processing Record 32 of Set 7 | pontianak
# Processing Record 33 of Set 7 | narayanpet
# Processing Record 34 of Set 7 | nongstoin
# Processing Record 35 of Set 7 | saint george
# Processing Record 36 of Set 7 | tautira
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 39 of Set 7 | mana
# Processing Record 40 of Set 7 | berlevag
# Processing Record 41 of Set 7 | viedma
# Processing Record 42 of Set 7 | basak
# Processing Record 43 of Set 7 | koumac
# Processing Record 44 of Set 7 | tshikapa
# Processing Record 45 of Set 7 | ekibastuz
# Processing Record 46 of Set 7 | alta floresta
# Processing Record 47 of Set 7 | alofi
# Processing Record 48 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 7 | svetlyy
# Processing Record 50 of Set 7 | bitung
# Processing Record 1 of Set 8 | kavaratti
# Processing Record 2 of Set 8 | paita
# Processing Record 3 of Set 8 | whitianga
# Processing Record 4 of Set 8 | touros
# Processing Record 5 of Set 8 | olafsvik
# Processing Record 6 of Set 8 | hambantota
# Processing Record 7 of Set 8 | tebingtinggi
# Processing Record 8 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 8 | plainview
# Processing Record 10 of Set 8 | sabang
# Processing Record 11 of Set 8 | tifton
# Processing Record 12 of Set 8 | nisia floresta
# Processing Record 13 of Set 8 | tezu
# Processing Record 14 of Set 8 | kollo
# Processing Record 15 of Set 8 | baiyin
# Processing Record 16 of Set 8 | hobyo
# Processing Record 17 of Set 8 | eureka
# Processing Record 18 of Set 8 | santa maria
# Processing Record 19 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 8 | kokkola
# Processing Record 21 of Set 8 | ballina
# Processing Record 22 of Set 8 | oro valley
# Processing Record 23 of Set 8 | trairi
# Processing Record 24 of Set 8 | bam
# Processing Record 25 of Set 8 | manggar
# Processing Record 26 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 8 | port moresby
# Processing Record 28 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 8 | sioux lookout
# Processing Record 30 of Set 8 | srednekolymsk
# Processing Record 31 of Set 8 | bayir
# Processing Record 32 of Set 8 | champerico
# Processing Record 33 of Set 8 | pinsk
# Processing Record 34 of Set 8 | vilaka
# Processing Record 35 of Set 8 | okhotsk
# Processing Record 36 of Set 8 | shar
# Processing Record 37 of Set 8 | krasnorechenskiy
# Processing Record 38 of Set 8 | presidente dutra
# Processing Record 39 of Set 8 | lisakovsk
# Processing Record 40 of Set 8 | shkoder
# Processing Record 41 of Set 8 | ladovskaya balka
# Processing Record 42 of Set 8 | swift current
# Processing Record 43 of Set 8 | buraydah
# Processing Record 44 of Set 8 | daru
# Processing Record 45 of Set 8 | kloulklubed
# Processing Record 46 of Set 8 | tortoli
# Processing Record 47 of Set 8 | kirovskiy
# Processing Record 48 of Set 8 | mapiripan
# Processing Record 49 of Set 8 | atasu
# Processing Record 50 of Set 8 | wajir
# Processing Record 1 of Set 9 | oussouye
# Processing Record 2 of Set 9 | wanning
# Processing Record 3 of Set 9 | esperance
# Processing Record 4 of Set 9 | fomboni
# Processing Record 5 of Set 9 | chokurdakh
# Processing Record 6 of Set 9 | vestmannaeyjar
# Processing Record 7 of Set 9 | norden
# Processing Record 8 of Set 9 | ciuchici
# Processing Record 9 of Set 9 | goderich
# Processing Record 10 of Set 9 | pangnirtung
# Processing Record 11 of Set 9 | north bend
# Processing Record 12 of Set 9 | alingsas
# Processing Record 13 of Set 9 | shakiso
# Processing Record 14 of Set 9 | sola
# Processing Record 15 of Set 9 | sistranda
# Processing Record 16 of Set 9 | mehamn
# Processing Record 17 of Set 9 | karratha
# Processing Record 18 of Set 9 | belmonte
# Processing Record 19 of Set 9 | cacador
# Processing Record 20 of Set 9 | beausejour
# Processing Record 21 of Set 9 | adamantina
# Processing Record 22 of Set 9 | salto
# Processing Record 23 of Set 9 | brookings
# Processing Record 24 of Set 9 | camopi
# Processing Record 25 of Set 9 | funadhoo
# Processing Record 26 of Set 9 | prabumulih
# Processing Record 27 of Set 9 | arbroath
# Processing Record 28 of Set 9 | marsaxlokk
# Processing Record 29 of Set 9 | mangai
# Processing Record 30 of Set 9 | constantine
# Processing Record 31 of Set 9 | upernavik
# Processing Record 32 of Set 9 | linjiang
# Processing Record 33 of Set 9 | takhtamygda
# Processing Record 34 of Set 9 | brae
# Processing Record 35 of Set 9 | diglur
# Processing Record 36 of Set 9 | shingu
# Processing Record 37 of Set 9 | hasaki
# Processing Record 38 of Set 9 | eyl
# Processing Record 39 of Set 9 | shelburne
# Processing Record 40 of Set 9 | takoradi
# Processing Record 41 of Set 9 | marsh harbour
# Processing Record 42 of Set 9 | slave lake
# Processing Record 43 of Set 9 | kamenka
# Processing Record 44 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 9 | natal
# Processing Record 46 of Set 9 | bonthe
# Processing Record 47 of Set 9 | eydhafushi
# Processing Record 48 of Set 9 | sauce
# Processing Record 49 of Set 9 | paranaiba
# Processing Record 50 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 10 | haimen
# Processing Record 2 of Set 10 | taree
# Processing Record 3 of Set 10 | suez
# Processing Record 4 of Set 10 | semey
# Processing Record 5 of Set 10 | bhandara
# Processing Record 6 of Set 10 | delano
# Processing Record 7 of Set 10 | talara
# Processing Record 8 of Set 10 | buala
# Processing Record 9 of Set 10 | umea
# Processing Record 10 of Set 10 | kudahuvadhoo
# Processing Record 11 of Set 10 | khandyga
# Processing Record 12 of Set 10 | sambava
# Processing Record 13 of Set 10 | garoua boulai
# Processing Record 14 of Set 10 | dingle
# Processing Record 15 of Set 10 | ouadda
# Processing Record 16 of Set 10 | ambunti
# Processing Record 17 of Set 10 | ishigaki
# Processing Record 18 of Set 10 | mugur-aksy
# Processing Record 19 of Set 10 | rajauri
# Processing Record 20 of Set 10 | york
# Processing Record 21 of Set 10 | kirando
# Processing Record 22 of Set 10 | buchanan
# Processing Record 23 of Set 10 | along
# Processing Record 24 of Set 10 | rawson
# Processing Record 25 of Set 10 | saldanha
# Processing Record 26 of Set 10 | weligama
# Processing Record 27 of Set 10 | saint-michel-des-saints
# Processing Record 28 of Set 10 | kankaanpaa
# Processing Record 29 of Set 10 | victoria
# Processing Record 30 of Set 10 | bodden town
# Processing Record 31 of Set 10 | tyup
# Processing Record 32 of Set 10 | kokoda
# Processing Record 33 of Set 10 | dullewala
# Processing Record 34 of Set 10 | baykit
# Processing Record 35 of Set 10 | mahibadhoo
# Processing Record 36 of Set 10 | snyder
# Processing Record 37 of Set 10 | dodge city
# Processing Record 38 of Set 10 | olinda
# Processing Record 39 of Set 10 | oistins
# Processing Record 40 of Set 10 | agadez
# Processing Record 41 of Set 10 | marsa matruh
# Processing Record 42 of Set 10 | ancud
# Processing Record 43 of Set 10 | aborlan
# Processing Record 44 of Set 10 | mayumba
# Processing Record 45 of Set 10 | staryy nadym
# Processing Record 46 of Set 10 | kalmunai
# Processing Record 47 of Set 10 | beringovskiy
# Processing Record 48 of Set 10 | barra do garcas
# Processing Record 49 of Set 10 | hope
# Processing Record 50 of Set 10 | cabatuan
# Processing Record 1 of Set 11 | bilibino
# Processing Record 2 of Set 11 | san cristobal
# Processing Record 3 of Set 11 | denpasar
# Processing Record 4 of Set 11 | de aar
# Processing Record 5 of Set 11 | caravelas
# Processing Record 6 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 11 | kerema
# Processing Record 8 of Set 11 | nauta
# Processing Record 9 of Set 11 | independence
# Processing Record 10 of Set 11 | tacuarembo
# Processing Record 11 of Set 11 | tucuma
# Processing Record 12 of Set 11 | ewa beach
# Processing Record 13 of Set 11 | puerto ayacucho
# Processing Record 14 of Set 11 | bogorodskoye
# Processing Record 15 of Set 11 | ambanja
# Processing Record 16 of Set 11 | kualakapuas
# Processing Record 17 of Set 11 | camacha
# Processing Record 18 of Set 11 | zhigansk
# Processing Record 19 of Set 11 | belyy yar
# Processing Record 20 of Set 11 | henderson
# Processing Record 21 of Set 11 | ghauspur
# Processing Record 22 of Set 11 | lang son
# Processing Record 23 of Set 11 | bull savanna
# Processing Record 24 of Set 11 | great malvern
# Processing Record 25 of Set 11 | coolum beach
# Processing Record 26 of Set 11 | praia da vitoria
# Processing Record 27 of Set 11 | nizwa
# Processing Record 28 of Set 11 | stornoway
# Processing Record 29 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 11 | dera bugti
# Processing Record 31 of Set 11 | noumea
# Processing Record 32 of Set 11 | sirsa
# Processing Record 33 of Set 11 | saurimo
# Processing Record 34 of Set 11 | ziarat
# Processing Record 35 of Set 11 | morehead
# Processing Record 36 of Set 11 | tual
# Processing Record 37 of Set 11 | tucurui
# Processing Record 38 of Set 11 | lincoln
# Processing Record 39 of Set 11 | vestmanna
# Processing Record 40 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 41 of Set 11 | sobolevo
# Processing Record 42 of Set 11 | kondinskoye
# Processing Record 43 of Set 11 | pafos
# Processing Record 44 of Set 11 | mandalgovi
# Processing Record 45 of Set 11 | antofagasta
# Processing Record 46 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 47 of Set 11 | lokosovo
# Processing Record 48 of Set 11 | urumqi
# Processing Record 49 of Set 11 | port augusta
# Processing Record 50 of Set 11 | tura
# Processing Record 1 of Set 12 | devarkonda
# Processing Record 2 of Set 12 | terrace
# Processing Record 3 of Set 12 | baturaja
# Processing Record 4 of Set 12 | porto belo
# Processing Record 5 of Set 12 | brainerd
# Processing Record 6 of Set 12 | mount isa
# Processing Record 7 of Set 12 | gravdal
# Processing Record 8 of Set 12 | izhma
# Processing Record 9 of Set 12 | tudela
# Processing Record 10 of Set 12 | gidole
# Processing Record 11 of Set 12 | northam
# Processing Record 12 of Set 12 | tuysarkan
# City not found. Skipping...
# Processing Record 13 of Set 12 | asosa
# Processing Record 14 of Set 12 | palana
# Processing Record 15 of Set 12 | kamen-na-obi
# Processing Record 16 of Set 12 | omsukchan
# Processing Record 17 of Set 12 | hofn
# Processing Record 18 of Set 12 | namatanai
# Processing Record 19 of Set 12 | kilindoni
# Processing Record 20 of Set 12 | baniachang
# Processing Record 21 of Set 12 | atar
# Processing Record 22 of Set 12 | potoci
# Processing Record 23 of Set 12 | parakou
# Processing Record 24 of Set 12 | fredericksburg
# Processing Record 25 of Set 12 | kokopo
# Processing Record 26 of Set 12 | cap malheureux
# Processing Record 27 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 12 | faya
# Processing Record 29 of Set 12 | kyren
# Processing Record 30 of Set 12 | tupelo
# Processing Record 31 of Set 12 | kasongo-lunda
# Processing Record 32 of Set 12 | turbat
# Processing Record 33 of Set 12 | diego de almagro
# Processing Record 34 of Set 12 | east london
# Processing Record 35 of Set 12 | kurilsk
# Processing Record 36 of Set 12 | aitape
# Processing Record 37 of Set 12 | pietermaritzburg
# Processing Record 38 of Set 12 | nipawin
# Processing Record 39 of Set 12 | huangmei
# Processing Record 40 of Set 12 | lysyye gory
# Processing Record 41 of Set 12 | yining
# Processing Record 42 of Set 12 | kharan
# Processing Record 43 of Set 12 | puerto madryn
# Processing Record 44 of Set 12 | vikulovo
# Processing Record 45 of Set 12 | grindavik
# Processing Record 46 of Set 12 | kathu
# Processing Record 47 of Set 12 | penzance
# Processing Record 48 of Set 12 | leon
# Processing Record 49 of Set 12 | ogembo
# Processing Record 50 of Set 12 | boguchany
# Processing Record 1 of Set 13 | luau
# Processing Record 2 of Set 13 | coos bay
# Processing Record 3 of Set 13 | alice town
# Processing Record 4 of Set 13 | verkhoyansk
# Processing Record 5 of Set 13 | guaruja
# Processing Record 6 of Set 13 | nsanje
# Processing Record 7 of Set 13 | pervomayskoye
# Processing Record 8 of Set 13 | yichun
# Processing Record 9 of Set 13 | the valley
# Processing Record 10 of Set 13 | dongsheng
# Processing Record 11 of Set 13 | bahia blanca
# Processing Record 12 of Set 13 | honningsvag
# Processing Record 13 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 13 | helena
# Processing Record 15 of Set 13 | simpang
# Processing Record 16 of Set 13 | nantucket
# Processing Record 17 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 18 of Set 13 | vanavara
# Processing Record 19 of Set 13 | poplar bluff
# Processing Record 20 of Set 13 | mitu
# Processing Record 21 of Set 13 | lerwick
# Processing Record 22 of Set 13 | kirensk
# Processing Record 23 of Set 13 | tigre
# Processing Record 24 of Set 13 | comodoro rivadavia
# Processing Record 25 of Set 13 | mocuba
# Processing Record 26 of Set 13 | muros
# Processing Record 27 of Set 13 | port-gentil
# Processing Record 28 of Set 13 | sosnovo-ozerskoye
# Processing Record 29 of Set 13 | nuuk
# Processing Record 30 of Set 13 | sokolo
# Processing Record 31 of Set 13 | labytnangi
# Processing Record 32 of Set 13 | aksarka
# Processing Record 33 of Set 13 | chimore
# Processing Record 34 of Set 13 | kieta
# Processing Record 35 of Set 13 | namuac
# Processing Record 36 of Set 13 | kyzyl
# Processing Record 37 of Set 13 | dezhou
# Processing Record 38 of Set 13 | urucui
# Processing Record 39 of Set 13 | inhambane
# Processing Record 40 of Set 13 | homer
# Processing Record 41 of Set 13 | nieuw nickerie
# Processing Record 42 of Set 13 | matsanga
# City not found. Skipping...
# Processing Record 43 of Set 13 | manthani
# Processing Record 44 of Set 13 | whyalla
# Processing Record 45 of Set 13 | juneau
# Processing Record 46 of Set 13 | andenes
# Processing Record 47 of Set 13 | okha
# Processing Record 48 of Set 13 | tarnow
# Processing Record 49 of Set 13 | koltubanovskiy
# Processing Record 50 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 14 | reinosa
# Processing Record 2 of Set 14 | ulaangom
# Processing Record 3 of Set 14 | krasnovishersk
# Processing Record 4 of Set 14 | segezha
# Processing Record 5 of Set 14 | selaphum
# Processing Record 6 of Set 14 | grass valley
# Processing Record 7 of Set 14 | abrau-dyurso
# Processing Record 8 of Set 14 | kashi
# Processing Record 9 of Set 14 | chivilcoy
# Processing Record 10 of Set 14 | yetkul
# Processing Record 11 of Set 14 | marzuq
# Processing Record 12 of Set 14 | tilichiki
# Processing Record 13 of Set 14 | kotelnich
# Processing Record 14 of Set 14 | liling
# Processing Record 15 of Set 14 | los llanos de aridane
# Processing Record 16 of Set 14 | saint-denis
# Processing Record 17 of Set 14 | quatre cocos
# Processing Record 18 of Set 14 | adrar
# Processing Record 19 of Set 14 | naliya
# Processing Record 20 of Set 14 | lodja
# Processing Record 21 of Set 14 | wajid
# Processing Record 22 of Set 14 | port keats
# Processing Record 23 of Set 14 | la roda
# Processing Record 24 of Set 14 | asyut
# Processing Record 25 of Set 14 | banjul
# Processing Record 26 of Set 14 | velingara
# Processing Record 27 of Set 14 | dobryanka
# Processing Record 28 of Set 14 | kapit
# Processing Record 29 of Set 14 | oda
# Processing Record 30 of Set 14 | zhanaozen
# Processing Record 31 of Set 14 | moa
# Processing Record 32 of Set 14 | palmer
# Processing Record 33 of Set 14 | half moon bay
# Processing Record 34 of Set 14 | mendahara
# City not found. Skipping...
# Processing Record 35 of Set 14 | villa guerrero
# Processing Record 36 of Set 14 | oga
# Processing Record 37 of Set 14 | markova
# Processing Record 38 of Set 14 | nouakchott
# Processing Record 39 of Set 14 | tarrafal
# Processing Record 40 of Set 14 | moindou
# Processing Record 41 of Set 14 | flinders
# Processing Record 42 of Set 14 | zaraza
# Processing Record 43 of Set 14 | bell ville
# Processing Record 44 of Set 14 | rio grande
# Processing Record 45 of Set 14 | novouzensk
# Processing Record 46 of Set 14 | suleja
# Processing Record 47 of Set 14 | seguin
# Processing Record 48 of Set 14 | kungurtug
# Processing Record 49 of Set 14 | koster
# Processing Record 50 of Set 14 | novaya lyalya
# Processing Record 1 of Set 15 | jiuquan
# Processing Record 2 of Set 15 | sao felix do xingu
# Processing Record 3 of Set 15 | inhumas
# Processing Record 4 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 15 | vinh
# Processing Record 6 of Set 15 | sao jose da coroa grande
# Processing Record 7 of Set 15 | burns lake
# Processing Record 8 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 15 | port macquarie
# Processing Record 10 of Set 15 | marawi
# Processing Record 11 of Set 15 | otjimbingwe
# Processing Record 12 of Set 15 | vao
# Processing Record 13 of Set 15 | shetpe
# Processing Record 14 of Set 15 | niamey
# Processing Record 15 of Set 15 | sungaipenuh
# Processing Record 16 of Set 15 | beidao
# Processing Record 17 of Set 15 | bathsheba
# Processing Record 18 of Set 15 | hauterive
# Processing Record 19 of Set 15 | fort william
# Processing Record 20 of Set 15 | dandong
# Processing Record 21 of Set 15 | yumen
# Processing Record 22 of Set 15 | sandwick
# Processing Record 23 of Set 15 | bossier city
# Processing Record 24 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 25 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 15 | samarai
# Processing Record 27 of Set 15 | werda
# Processing Record 28 of Set 15 | taraz
# Processing Record 29 of Set 15 | mackay
# Processing Record 30 of Set 15 | verkh-neyvinskiy
# Processing Record 31 of Set 15 | oak harbor
# Processing Record 32 of Set 15 | herat
# Processing Record 33 of Set 15 | fojnica
# Processing Record 34 of Set 15 | anloga
# Processing Record 35 of Set 15 | hudson bay
# Processing Record 36 of Set 15 | rafsanjan
# Processing Record 37 of Set 15 | bayangol
# Processing Record 38 of Set 15 | pathein
# Processing Record 39 of Set 15 | sechura
# Processing Record 40 of Set 15 | pascagoula
# Processing Record 41 of Set 15 | moranbah
# Processing Record 42 of Set 15 | porto novo
# Processing Record 43 of Set 15 | yakeshi
# Processing Record 44 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 45 of Set 15 | puerto gaitan
# Processing Record 46 of Set 15 | thatta
# Processing Record 47 of Set 15 | krasnoselkup
# Processing Record 48 of Set 15 | churachandpur
# Processing Record 49 of Set 15 | porosozero
# Processing Record 50 of Set 15 | deming
# Processing Record 1 of Set 16 | gladstone
# Processing Record 2 of Set 16 | iskateley
# Processing Record 3 of Set 16 | yarensk
# Processing Record 4 of Set 16 | dakar
# Processing Record 5 of Set 16 | sorland
# Processing Record 6 of Set 16 | huilong
# Processing Record 7 of Set 16 | agsu
# City not found. Skipping...
# Processing Record 8 of Set 16 | lavrentiya
# Processing Record 9 of Set 16 | walvis bay
# Processing Record 10 of Set 16 | rocha
# Processing Record 11 of Set 16 | san juan
# Processing Record 12 of Set 16 | thinadhoo
# Processing Record 13 of Set 16 | bilma
# Processing Record 14 of Set 16 | letlhakane
# Processing Record 15 of Set 16 | sangar
# Processing Record 16 of Set 16 | beipiao
# Processing Record 17 of Set 16 | coshocton
# Processing Record 18 of Set 16 | ukiah
# Processing Record 19 of Set 16 | bezhanitsy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# [{'City': 'Hami', 'Lat': 42.8, 'Lng': 93.45, 'Max Temp': 60.8, 'Humidity': 16, 'Cloudiness': 89, 'Wind Speed': 10.45, 'Country': 'CN', 'Description': 'overcast clouds'}, {'City': 'Butaritari', 'Lat': 3.0707, 'Lng': 172.7902, 'Max Temp': 82.83, 'Humidity': 65, 'Cloudiness': 3, 'Wind Speed': 8.66, 'Country': 'KI', 'Description': 'clear sky'}, {'City': 'Khuzhir', 'Lat': 53.1939, 'Lng': 107.3397, 'Max Temp': 43.88, 'Humidity': 60, 'Cloudiness': 45, 'Wind Speed': 2.98, 'Country': 'RU', 'Description': 'scattered clouds'}, {'City': 'Kutum', 'Lat': 14.2, 'Lng': 24.6667, 'Max Temp': 72.72, 'Humidity': 19, 'Cloudiness': 52, 'Wind Speed': 18.66, 'Country': 'SD', 'Description': 'broken clouds'}, {'City': 'Vaini', 'Lat': -21.2, 'Lng': -175.2, 'Max Temp': 78.96, 'Humidity': 57, 'Cloudiness': 75, 'Wind Speed': 8.05, 'Country': 'TO', 'Description': 'broken clouds'}, {'City': 'Kodiak', 'Lat': 57.79, 'Lng': -152.4072, 'Max Temp': 41.36, 'Humidity': 88, 'Cloudiness': 100, 'Wind Speed': 4.43, 'Country': 'US', 'Description': 'overcast clouds'}, {'City': 'Narsaq', 'Lat': 60.9167, 'Lng': -46.05, 'Max Temp': 37.62, 'Humidity': 36, 'Cloudiness': 0, 'Wind Speed': 6.11, 'Country': 'GL', 'Description': 'clear sky'}, {'City': 'Port Lincoln', 'Lat': -34.7333, 'Lng': 135.8667, 'Max Temp': 73.87, 'Humidity': 43, 'Cloudiness': 100, 'Wind Speed': 10.94, 'Country': 'AU', 'Description': 'light rain'}, {'City': 'Qaanaaq', 'Lat': 77.484, 'Lng': -69.3632, 'Max Temp': 28.17, 'Humidity': 95, 'Cloudiness': 100, 'Wind Speed': 3.29, 'Country': 'GL', 'Description': 'light snow'}, {'City': 'Henties Bay', 'Lat': -22.116, 'Lng': 14.2845, 'Max Temp': 56.86, 'Humidity': 93, 'Cloudiness': 86, 'Wind Speed': 10.67, 'Country': 'NA', 'Description': 'overcast clouds'}, {'City': 'Bredasdorp', 'Lat': -34.5322, 'Lng': 20.0403, 'Max Temp': 58.28, 'Humidity': 94, 'Cloudiness': 3, 'Wind Speed': 11.7, 'Country': 'ZA', 'Description': 'clear sky'}, {'City': 'Nelson Bay', 'Lat': -32.7167, 'Lng': 152.15, 'Max Temp': 68.11, 'Humidity': 66, 'Cloudiness': 55, 'Wind Speed': 4, 'Country': 'AU', 'Description': 'broken clouds'}, {'City': 'Lompoc', 'Lat': 34.6391, 'Lng': -120.4579, 'Max Temp': 57.13, 'Humidity': 84, 'Cloudiness': 1, 'Wind Speed': 3.44, 'Country': 'US', 'Description': 'clear sky'}, {'City': 'Gat', 'Lat': 31.61, 'Lng': 34.7642, 'Max Temp': 68.4, 'Humidity': 100, 'Cloudiness': 100, 'Wind Speed': 1.61, 'Country': 'IL', 'Description': 'overcast clouds'}, {'City': 'San Jose', 'Lat': 37.3394, 'Lng': -121.895, 'Max Temp': 63.36, 'Humidity': 49, 'Cloudiness': 75, 'Wind Speed': 1.01, 'Country': 'US', 'Description': 'broken clouds'}, {'City': 'Yendi', 'Lat': 9.4427, 'Lng': -0.0099, 'Max Temp': 72.66, 'Humidity': 96, 'Cloudiness': 68, 'Wind Speed': 2.24, 'Country': 'GH', 'Description': 'moderate rain'}, {'City': 'Pisco', 'Lat': -13.7, 'Lng': -76.2167, 'Max Temp': 61.02, 'Humidity': 82, 'Cloudiness': 0, 'Wind Speed': 9.22, 'Country': 'PE', 'Description': 'clear sky'}, {'City': 'Pevek', 'Lat': 69.7008, 'Lng': 170.3133, 'Max Temp': 18.55, 'Humidity': 94, 'Cloudiness': 100, 'Wind Speed': 14.12, 'Country': 'RU', 'Description': 'overcast clouds'}, {'City': 'Kui Buri', 'Lat': 12.0828, 'Lng': 99.8543, 'Max Temp': 86, 'Humidity': 67, 'Cloudiness': 82, 'Wind Speed': 5.39, 'Country': 'TH', 'Description': 'broken clouds'}, {'City': 'Nago', 'Lat': 26.5881, 'Lng': 127.9761, 'Max Temp': 81.03, 'Humidity': 55, 'Cloudiness': 66, 'Wind Speed': 10.67, 'Country': 'JP', 'Description': 'broken clouds'}, {'City': 'Punta Arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max Temp': 51.91, 'Humidity': 71, 'Cloudiness': 0, 'Wind Speed': 6.91, 'Country': 'CL', 'Description': 'clear sky'}, {'City': 'Sapa', 'Lat': 5.1544, 'Lng': 120.3241, 'Max Temp': 85.24, 'Humidity': 69, 'Cloudiness': 52, 'Wind Speed': 6.29, 'Country': 'PH', 'Description': 'broken clouds'}, {'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 75, 'Humidity': 75, 'Cloudiness': 2, 'Wind Speed': 19.75, 'Country': 'PF', 'Description': 'light rain'}, {'Ci ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_order = ['City','Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness','Wind Speed','Description']
city_data_df = city_data_df[new_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hami      CN  42.8000   93.4500     60.80        16          89
# 1    Butaritari      KI   3.0707  172.7902     82.83        65           3
# 2       Khuzhir      RU  53.1939  107.3397     43.88        60          45
# 3         Kutum      SD  14.2000   24.6667     72.72        19          52
# 4         Vaini      TO -21.2000 -175.2000     78.96        57          75
# 5        Kodiak      US  57.7900 -152.4072     41.36        88         100
# 6        Narsaq      GL  60.9167  -46.0500     37.62        36           0
# 7  Port Lincoln      AU -34.7333  135.8667     73.87        43         100
# 8       Qaanaaq      GL  77.4840  -69.3632     28.17        95         100
# 9   Henties Bay      NA -22.1160   14.2845     56.86        93          86
#
#    Wind Speed       Description
# 0       10.45   overcast clouds
# 1        8.66         clear sky
# 2        2.98  scattered clouds
# 3       18.66     broken clouds
# 4        8.05     broken clouds
# 5        4.43   overcast clouds
# 6        6.11         clear sky
# 7       10.94        light rain
# 8        3.29        light snow
# 9       10.67   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
